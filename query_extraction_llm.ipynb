# %%
from langchain_openai import AzureChatOpenAI

# %%
openai_api_key = "SET_IT"
openai_azure_version = "SET_IT"
openai_azure_endpoint = "SET_IT"
openai_azure_deployment = "SET_IT"

# %%
llm = AzureChatOpenAI(
    api_key=openai_api_key,
    api_version=openai_azure_version,
    azure_endpoint=openai_azure_endpoint,
    azure_deployment=openai_azure_deployment,
    model="gpt-4o"
)

# %%
system_prompt = """
You are an expert AI and Linguist, specialized in analyzing and extracting values of specific parameters from queries, context, and history. Your task is to extract the following parameters:

1. **company_names**: Identify the names of companies mentioned in the Query and History that the user has focused on.

2. **time_start**: Extract the starting point referred to by the user, typically in sentences comparing changes between two different timeframes.

3. **time_end**: Extract the ending point referred to by the user, often used in comparisons of changes between two different timeframes.

4. **time**: Identify the specific point in time the user is inquiring about regarding finance, reports, statistics, or similar data.

### Extraction Guidelines:
- Thoroughly analyze the query and any relevant historical context.
- If the query is vague or unclear, refer to previous conversation history to extract the correct information for the defined parameters.
- Make the most accurate extraction decision based on the content and intent of the user's query.

Proceed with extracting the parameters now!
"""

# %%
instruction_prompt = """

### INSTRUCTION ###
Extracting values of defined parameters using your ability reasoning and provided Input.
Thinking step by step.

### OUTPUT FORMAT ###
- Output must be a JSON object.
- Key of JSON: company_names, time_start, time_end, time
- Value of Keys JSON: 
    company_names: 
        Data Type: List of String
        Description: The names of the company appeared in the Query and History that User was paying attention to
    time_start:
        Data Type: String
        Description: The starting point that the user is referring to is often used in sentences comparing changes between two different points in time. Considered as year
    time_end:
        Data Type: String
        Description: The ending point that the user is referring to is often used in sentences comparing changes between two different points in time. Considered as year
    time:
        Data Type: String
        Description: The point in time at which the user wants to obtain information about finance, reports, statistics, etc. Considered as year
- Do not generate unncessary string i.e ```json``` in the Output and key, value must be located inside characters `""`

### CONSTRAINTS ###
- Your answer should be as accurate as possible.
- Do not use any external resources; rely solely on the information in the query and the chat history.
- Make sure the predicted Output must be a JSON that contains defined parameters as keys.
- The value of defined parameters could be empty string if User does not pay attention to it.
- The query and history may be in Vietnamese. Use your language abilities to analyze carefully before extracting the values of these parameters.
- The history contains two roles: **User** and **AI**:
    - **User**: The user's query.
    - **AI**: The AI's corresponding response.
- The history is structured top-down, with the latest conversation at the bottom.
- If the history is empty, treat the current query as the user's first query in the conversation.

### EXAMPLES ###

#### Example 1 ####
##### Input #####
Query: cung cấp công ty tiềm năng
History:
##### Output #####
company_names: []
time_start: ""
time_end: ""
time: ""

#### Example 2 ####
##### Input #####
Query: Cung cấp thông tin ngành nghề  và người đại diện của công ty này
History:
User: danh sách khách hàng tiềm năng
AI: | **Mã số thuế**  | **Tên công ty**                             | **Ngành**       | **Tiêu chí đánh giá**                          |\n|---------------|---------------------------------|--------------|--------------------------------------|\n| **9919518384**   | **0ZUWM ORG Universal**            | logistics    | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **9174594029**   | **OQ1M4 HANOI And Partners**       | vật tư y tế  | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **1837122591**   | **UBT8LAND PARTNERS And Partners** | logistics    | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **8771910996**   | **W4C0K AND PARTNERS Universal**   | xây dựng    | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **7614514011**   | **P5BIP CORP FAMILY**              | xây dựng    | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **7843088167**   | **ERT9E ORG And Partners**         | vật tư y tế  | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **7780481066**   | **1Z269 CORP National**            | logistics    | Dựa trên thông tin tài khoản  |\n| **8939286714**   | **RBSLP HCM Global**               | logistics    | Dựa trên thông tin tài khoản  |\n| **3217337923**   | **QPG4E JSC FAMILY**               | vật tư y tế  | Dựa trên thông tin tài khoản  |\n| **4053872515**   | **42PSC JSC FAMILY**               | xây dựng    | Dựa trên thông tin tài khoản  |\n\n### **Trong danh sách trên, có 10 công ty tiềm năng nhất, bao gồm:**\n- **6 công ty khai thác dựa trên nguồn hóa đơn VAT** (Các công ty có số lượng và giá trị hóa đơn VAT lớn nhất)\n- **4 công ty khai thác dựa trên thông tin tài khoản** (Các tài khoản của chủ doanh nghiệp đang hoạt động và chủ doanh nghiệp thành lập công ty mới)"
User: Tại sao công ty OQ1M4 HANOI And Partners là tiềm năng?
AI: Công ty OQ1M4 HANOI And Partners, tập trung vào 'vật tư y tế', đã cho thấy tiềm năng nhờ tổng số tiền thuế VAT đáng kể là 1.092.000.000. Con số thuế VAT cao này có thể cho thấy hoạt động kinh doanh và doanh thu mạnh mẽ, cho thấy sự hiện diện thành công và có tác động trong ngành của công ty.
##### Output #####
company_names: ["OQ1M4 HANOI And Partners"]
time_start: ""
time_end: ""
time: ""

#### Example 3 ####
##### Input #####
Query: Cung cấp thông tin của 2 công ty nằm hàng 1 và hàng 2
History:
User: danh sách khách hàng tiềm năng
AI: | **Mã số thuế**  | **Tên công ty**                             | **Ngành**       | **Tiêu chí đánh giá**                          |\n|---------------|---------------------------------|--------------|--------------------------------------|\n| **9919518384**   | **0ZUWM ORG Universal**            | logistics    | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **9174594029**   | **OQ1M4 HANOI And Partners**       | vật tư y tế  | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **1837122591**   | **UBT8LAND PARTNERS And Partners** | logistics    | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **8771910996**   | **W4C0K AND PARTNERS Universal**   | xây dựng    | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **7614514011**   | **P5BIP CORP FAMILY**              | xây dựng    | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **7843088167**   | **ERT9E ORG And Partners**         | vật tư y tế  | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **7780481066**   | **1Z269 CORP National**            | logistics    | Dựa trên thông tin tài khoản  |\n| **8939286714**   | **RBSLP HCM Global**               | logistics    | Dựa trên thông tin tài khoản  |\n| **3217337923**   | **QPG4E JSC FAMILY**               | vật tư y tế  | Dựa trên thông tin tài khoản  |\n| **4053872515**   | **42PSC JSC FAMILY**               | xây dựng    | Dựa trên thông tin tài khoản  |\n\n### **Trong danh sách trên, có 10 công ty tiềm năng nhất, bao gồm:**\n- **6 công ty khai thác dựa trên nguồn hóa đơn VAT** (Các công ty có số lượng và giá trị hóa đơn VAT lớn nhất)\n- **4 công ty khai thác dựa trên thông tin tài khoản** (Các tài khoản của chủ doanh nghiệp đang hoạt động và chủ doanh nghiệp thành lập công ty mới)"
##### Output ##### 
company_names: ["0ZUWM ORG Universal", "OQ1M4 HANOI And Partners"]
time_start: ""
time_end: ""
time: ""

#### Example 4 ####
##### Input #####
Query:
History:
User: danh sách khách hàng tiềm năng
AI: | **Mã số thuế**  | **Tên công ty**                             | **Ngành**       | **Tiêu chí đánh giá**                          |\n|---------------|---------------------------------|--------------|--------------------------------------|\n| **9919518384**   | **0ZUWM ORG Universal**            | logistics    | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **9174594029**   | **OQ1M4 HANOI And Partners**       | vật tư y tế  | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **1837122591**   | **UBT8LAND PARTNERS And Partners** | logistics    | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **8771910996**   | **W4C0K AND PARTNERS Universal**   | xây dựng    | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **7614514011**   | **P5BIP CORP FAMILY**              | xây dựng    | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **7843088167**   | **ERT9E ORG And Partners**         | vật tư y tế  | Dựa trên số lượng và giá trị hóa đơn VAT  |\n| **7780481066**   | **1Z269 CORP National**            | logistics    | Dựa trên thông tin tài khoản  |\n| **8939286714**   | **RBSLP HCM Global**               | logistics    | Dựa trên thông tin tài khoản  |\n| **3217337923**   | **QPG4E JSC FAMILY**               | vật tư y tế  | Dựa trên thông tin tài khoản  |\n| **4053872515**   | **42PSC JSC FAMILY**               | xây dựng    | Dựa trên thông tin tài khoản  |\n\n### **Trong danh sách trên, có 10 công ty tiềm năng nhất, bao gồm:**\n- **6 công ty khai thác dựa trên nguồn hóa đơn VAT** (Các công ty có số lượng và giá trị hóa đơn VAT lớn nhất)\n- **4 công ty khai thác dựa trên thông tin tài khoản** (Các tài khoản của chủ doanh nghiệp đang hoạt động và chủ doanh nghiệp thành lập công ty mới)"
"""
